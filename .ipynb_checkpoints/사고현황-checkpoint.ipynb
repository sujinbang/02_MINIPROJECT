# %% [markdown]
# # 월별 이륜차 사고건수

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_month_total = pd.DataFrame()

# %%
df_month = pd.read_excel('./data/월별_서울_이륜차사고.xls')
df_month
# Out:
#              시도  시군구  사고년도  2018 2018.1 2018.2 2018.3 2018.4 2018.5 2018.6  \
# 0            시도  시군구  사고년도    합계    01월    02월    03월    04월    05월    06월
# 1            합계   합계  사고건수  3331    215    187    261    292    270    306
# 2            합계   합계  사망자수    35      0      0      4      3      3      4
# 3            합계   합계  부상자수  4195    287    224    305    356    345    365
# 4            서울   합계  사고건수  3331    215    187    261    292    270    306
# ..          ...  ...   ...   ...    ...    ...    ...    ...    ...    ...
# 78           서울  강북구  부상자수   254     50      4     16     24     23     17
# 79           서울  금천구  사고건수   101      5      5     12     11      8      9
# 80           서울  금천구  사망자수     0      0      0      0      0      0      0
# 81           서울  금천구  부상자수   131      6      5     12     13     16     12
# 82  출처) 도로교통공단.  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     ... 2021.3 2021.4 2021.5 2021.6 2021.7 2021.8 2021.9 2021.10 2021.11  \
# 0   ...    03월    04월    05월    06월    07월    08월    09월     10월     11월
# 1   ...    282    362    347    383    422    368    342     356     290
# 2   ...      1      0      2      6      5      5      7       5       2
# 3   ...    345    470    448    473    522    462    430     461     375
# 4   ...    282    362    347    383    422    368    342     356     290
# ..  ...    ...    ...    ...    ...    ...    ...    ...     ...     ...
# 78  ...     17     16     16     30     21     24     10      16      23
# 79  ...      8     10     11     11     12     10      7      10       9
# 80  ...      0      0      0      0      2      0      0       1       0
# 81  ...      8     14     18     14     17     15     13      12      14
# 82  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN
#
#    2021.12
# 0      12월
# 1      352
# 2        1
# 3      482
# 4      352
# ..     ...
# 78      29
# 79       9
# 80       0
# 81      11
# 82     NaN
#
# [83 rows x 55 columns]

# %%
df_month = pd.read_excel('./data/월별_서울_이륜차사고.xls')
df_month = df_month.T
df_month = df_month.iloc[:,:4]
df_month = df_month.drop('시도')
df_month = df_month.drop('시군구')
df_month = df_month.drop('사고년도')
df_month = df_month.set_index(0)
df_month.columns=['사고건수','사망자수','부상자수']
df_month = df_month.drop('합계')
df_month = df_month[['사고건수']]
df_month_2018 = df_month.iloc[0:12,:]
df_month_2019 = df_month.iloc[12:24,:]
df_month_2020 = df_month.iloc[24:36,:]
df_month_2021 = df_month.iloc[36:,:]

# %%
df_month_total = pd.concat([df_month_total,df_month_2018,df_month_2019,df_month_2020,df_month_2021],axis=1)
df_month_total
# Out:
#     사고건수 사고건수 사고건수 사고건수
# 0
# 01월  215  239  271  290
# 02월  187  227  326  241
# 03월  261  290  289  282
# 04월  292  366  322  362
# 05월  270  381  349  347
# 06월  306  398  347  383
# 07월  295  384  347  422
# 08월  310  383  349  368
# 09월  276  367  342  342
# 10월  327  365  376  356
# 11월  322  391  333  290
# 12월  270  273  365  352

# %%
df_month_total.columns=['2018','2019','2020','2021']

# %%
df_month_total = df_month_total.astype(int)

# %%
plt.figure(figsize=(16,10))
plt.rc("font", family = "Malgun Gothic", size=10)
sns.heatmap(df_month_total, annot=True, fmt='.0f', cmap='rocket_r')
plt.title("서울 지역 월별 이륜차 사고건수")
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.title("서울 지역 요일별 이륜차 사고건수")
plt.plot(df_month_total)
# Out:
# [<matplotlib.lines.Line2D at 0x2138334c040>,
#  <matplotlib.lines.Line2D at 0x2138334c160>,
#  <matplotlib.lines.Line2D at 0x2138334c1f0>,
#  <matplotlib.lines.Line2D at 0x2138334c7f0>]

# %% [markdown]
# # 일별 이륜차 사고건수

# %%
import pandas as pd

# %%
df_day_total = pd.DataFrame()

# %%
df_day = pd.read_excel('./data/요일별_서울_이륜차사고.xls')
df_day = df_day.T
df_day = df_day.iloc[:,:4]
df_day = df_day.drop('시도')
df_day = df_day.drop('시군구')
df_day = df_day.drop('사고년도')
df_day = df_day.set_index(0)
df_day.columns=['사고건수','사망자수','부상자수']
df_day = df_day.drop('합계')
df_day = df_day[['사고건수']]
df_day_2018 = df_day.iloc[0:7,:]
df_day_2019 = df_day.iloc[7:14,:]
df_day_2020 = df_day.iloc[14:21,:]
df_day_2021 = df_day.iloc[21:,:]

# %%
df_day_total = pd.concat([df_day_total,df_day_2018,df_day_2019,df_day_2020,df_day_2021],axis=1)
df_day_total
# Out:
#   사고건수 사고건수 사고건수 사고건수
# 0
# 일  387  486  516  474
# 월  445  575  530  546
# 화  438  580  539  577
# 수  471  581  637  574
# 목  507  572  546  565
# 금  521  632  634  688
# 토  562  638  614  611

# %%
df_day_total.columns=['2018','2019','2020','2021']
df_day_total = df_day_total.astype(int)

# %%
plt.figure(figsize=(16,10))
plt.rc("font", family = "Malgun Gothic", size=10)
sns.heatmap(df_day_total, annot=True, fmt='.0f', cmap='rocket_r')
plt.title("서울 지역 요일별 이륜차 사고건수")
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.title("서울 지역 요일별 이륜차 사고건수")
plt.plot(df_day_total)
# Out:
# [<matplotlib.lines.Line2D at 0x21383ea8490>,
#  <matplotlib.lines.Line2D at 0x21383ea8460>,
#  <matplotlib.lines.Line2D at 0x21383ea8610>,
#  <matplotlib.lines.Line2D at 0x21383ea8730>]

# %% [markdown]
# # 시간대별 이륜차 사고건수

# %%
df_time_total = pd.DataFrame()

# %%
df_time = pd.read_excel('./data/시간대별_서울_이륜차사고.xls')
df_time = df_time.T
df_time = df_time.iloc[:,:4]
df_time = df_time.drop('시도')
df_time = df_time.drop('시군구')
df_time = df_time.drop('사고년도')
df_time = df_time.set_index(0)
df_time.columns=['사고건수','사망자수','부상자수']
df_time = df_time.drop('합계')
df_time = df_time[['사고건수']]
df_time
df_time_2018 = df_time.iloc[0:12,:]
df_time_2019 = df_time.iloc[12:24,:]
df_time_2020 = df_time.iloc[24:36,:]
df_time_2021 = df_time.iloc[36:,:]
df_time_2018
# Out:
#         사고건수
# 0
# 00시-02시  221
# 02시-04시  139
# 04시-06시  103
# 06시-08시  126
# 08시-10시  202
# 10시-12시  214
# 12시-14시  319
# 14시-16시  385
# 16시-18시  384
# 18시-20시  511
# 20시-22시  402
# 22시-24시  325

# %%
df_time_total = pd.concat([df_time_total,df_time_2018,df_time_2019,df_time_2020,df_time_2021],axis=1)
df_time_total
# Out:
#         사고건수 사고건수 사고건수 사고건수
# 0
# 00시-02시  221  225  203  157
# 02시-04시  139  139  118   77
# 04시-06시  103  124   99   67
# 06시-08시  126  131   95   94
# 08시-10시  202  245  204  181
# 10시-12시  214  306  329  354
# 12시-14시  319  477  453  513
# 14시-16시  385  412  447  431
# 16시-18시  384  494  469  493
# 18시-20시  511  617  650  728
# 20시-22시  402  521  523  546
# 22시-24시  325  373  426  394

# %%
df_time_total.columns=['2018','2019','2020','2021']
df_time_total = df_time_total.astype(int)

# %%
plt.figure(figsize=(16,10))
plt.rc("font", family = "Malgun Gothic", size=10)
sns.heatmap(df_time_total, annot=True, fmt='.0f', cmap='rocket_r')
plt.title("서울 지역 시간대별 이륜차 사고건수")
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.title("서울 지역 시간대별 이륜차 사고건수")
plt.plot(df_time_total)
# Out:
# [<matplotlib.lines.Line2D at 0x21383efcd00>,
#  <matplotlib.lines.Line2D at 0x21383efce50>,
#  <matplotlib.lines.Line2D at 0x21383f170d0>,
#  <matplotlib.lines.Line2D at 0x21383f171f0>]
